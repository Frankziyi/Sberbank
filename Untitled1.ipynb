# %%
import os
import sys
import operator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from com_util import *

# %%
train_df = pd.read_csv("./train.csv")

# %%
index = train_df['full_sq'] != 0

# %%
temp = train_df["price_doc"][index] / train_df["full_sq"][index]

# %%
datetime = pd.to_datetime(train_df["timestamp"][index]).dt

# %%
t = datetime.year * 100 + datetime.month

# %%
df = pd.DataFrame({'t':t, 'y':temp})

# %%
sns.pointplot(x='t', y='y', data=df)

sns.plt.show()
